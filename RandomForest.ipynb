# %% [markdown]
# <a href="https://colab.research.google.com/github/DhruvR-HWUD/DMML-Dubai-UG-Group-2/blob/Razin-Branch/RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


url = 'https://raw.githubusercontent.com/DhruvR-HWUD/DMML-Dubai-UG-Group-2/refs/heads/Razin-Branch/Datasets/processed/tabular_data/brain_tumor_dataset.csv'
df = pd.read_csv(url).drop(columns=['Patient_ID'])

X = pd.get_dummies(df.drop(columns=['Histology']), drop_first=True)
y = LabelEncoder().fit_transform(df['Histology'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print("Random Forest Model Evaluation (Target = Histology):")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}\n")
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred)).plot(cmap='Greens')
plt.title("Random Forest Confusion Matrix")
plt.show()
# Out:
# Random Forest Model Evaluation (Target = Histology):
# Accuracy: 0.251
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.25      0.25      0.25      1481
#            1       0.28      0.29      0.28      1520
#            2       0.24      0.24      0.24      1494
#            3       0.23      0.23      0.23      1505
#
#     accuracy                           0.25      6000
#    macro avg       0.25      0.25      0.25      6000
# weighted avg       0.25      0.25      0.25      6000
#
# Confusion Matrix:
#  [[372 362 372 375]
#  [370 434 367 349]
#  [367 378 357 392]
#  [365 400 398 342]]

# %%
rf = RandomForestClassifier(
    n_estimators=150,
    max_depth=10,
    min_samples_split=5,
    min_samples_leaf=3,
    random_state=42,
    n_jobs=-1
)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print("Random Forest Model Evaluation (Target = Histology):")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}\n")
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred)).plot(cmap='Greens')
plt.title("Random Forest Confusion Matrix")
plt.show()
# Out:
# Random Forest Model Evaluation (Target = Histology):
# Accuracy: 0.246
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.23      0.20      0.21      1481
#            1       0.26      0.30      0.27      1520
#            2       0.24      0.24      0.24      1494
#            3       0.25      0.26      0.25      1505
#
#     accuracy                           0.25      6000
#    macro avg       0.25      0.25      0.24      6000
# weighted avg       0.25      0.25      0.25      6000
#
# Confusion Matrix:
#  [[289 421 374 397]
#  [318 449 359 394]
#  [316 435 353 390]
#  [320 441 357 387]]

# %%
rf = RandomForestClassifier(
    n_estimators=250,
    max_depth=15,
    class_weight='balanced',   # adjust for class imbalance
    max_features='sqrt',
    random_state=42,
    n_jobs=-1
)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

print("Random Forest Model Evaluation (Target = Histology):")
print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}\n")
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred)).plot(cmap='Greens')
plt.title("Random Forest Confusion Matrix")
plt.show()
# Out:
# Random Forest Model Evaluation (Target = Histology):
# Accuracy: 0.245
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.24      0.23      0.24      1481
#            1       0.27      0.27      0.27      1520
#            2       0.23      0.23      0.23      1494
#            3       0.24      0.25      0.24      1505
#
#     accuracy                           0.25      6000
#    macro avg       0.25      0.25      0.25      6000
# weighted avg       0.25      0.25      0.25      6000
#
# Confusion Matrix:
#  [[348 356 393 384]
#  [360 405 368 387]
#  [378 359 350 407]
#  [367 380 389 369]]
