# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'pandas'

# %%
url = 'https://raw.githubusercontent.com/DhruvR-HWUD/DMML-Dubai-UG-Group-2/refs/heads/Razin-Branch/Datasets/processed/tabular_data/brain_tumor_dataset.csv'
df = pd.read_csv(url).drop(columns=['Patient_ID'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 url = 'https://raw.githubusercontent.com/DhruvR-HWUD/DMML-Dubai-UG-Group-2/refs/heads/Razin-Branch/Datasets/processed/tabular_data/brain_tumor_dataset.csv'
# ----> 2 df = pd.read_csv(url).drop(columns=['Patient_ID'])
#
# NameError: name 'pd' is not defined

# %%
X = pd.get_dummies(df.drop(columns=['Histology']), drop_first=True)
y = LabelEncoder().fit_transform(df['Histology'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 X = pd.get_dummies(df.drop(columns=['Histology']), drop_first=True)
#       2 y = LabelEncoder().fit_transform(df['Histology'])
#
# NameError: name 'pd' is not defined
